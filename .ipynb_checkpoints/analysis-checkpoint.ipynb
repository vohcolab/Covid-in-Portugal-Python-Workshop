# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv",index_col=0)
vac = pd.read_csv("vacinas.csv",index_col=0)

# %%
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                   data_dados  confirmados  confirmados_arsnorte  \
# data
# 2020-02-26  26-02-2020 00:00            0                     0
# 2020-02-27  27-02-2020 00:00            0                     0
# 2020-02-28  28-02-2020 00:00            0                     0
# 2020-02-29  29-02-2020 00:00            0                     0
# 2020-01-03  01-03-2020 00:00            0                     0
# ...                      ...          ...                   ...
# 2021-05-30  30-05-2021 00:00       848658                340298
# 2021-05-31  31-05-2021 00:00       849093                340411
# 2021-01-06  01-06-2021 00:00       849538                340525
# 2021-02-06  02-06-2021 00:00       850262                340737
# 2021-03-06  03-06-2021 00:00       851031                340977
#
#             confirmados_arscentro  confirmados_arslvt  \
# data
# 2020-02-26                      0                   0
# 2020-02-27                      0                   0
# ...

# %%
df[["ativos","internados_enfermaria","obitos_m","obitos_f"]].plot()

# %%
df = df[["confirmados"]]

# %%
df["new"].tail(n=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2a91bc0d9778> in <module>
# ----> 1 df["new"].tail(n=20)
#
# ...

# %%
df = df[["ativos","confirmados_novos","obitos"]]

# %%
df["obitos"] = df["obitos"].diff()

# %%
df.tail(n=50)
# Out:
#               ativos  confirmados_novos  obitos
# data
# 28-12-2020   68307.0               2093    58.0
# 29-12-2020   65457.0               3336    74.0
# 30-12-2020   68205.0               6049    79.0
# 31-12-2020   72496.0               7627    76.0
# 01-01-2021   74989.0               6951    66.0
# 02-01-2021   76675.0               3241    73.0
# 03-01-2021   77601.0               3384    73.0
# 04-01-2021   80008.0               4369    78.0
# 05-01-2021   80183.0               4956    90.0
# 06-01-2021   87004.0              10027    91.0
# 07-01-2021   93360.0               9927    95.0
# 08-01-2021   98938.0              10176   118.0
# 09-01-2021  102406.0               9478   111.0
# 10-01-2021  106778.0               7502   102.0
# 11-01-2021  109312.0               5604   122.0
# 12-01-2021  110388.0               7259   155.0
# 13-01-2021  116328.0              10556   156.0
# 14-01-2021  121815.0              10698   148.0
# ...
